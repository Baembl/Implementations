# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
f = pd.read_csv(r"C:\Users\UAE\Downloads\Abdur Rafay\Implementations\Implementations\Regression\Linear Regression\Salary_Data.csv")

# %%
f.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
f.shape
# Out:
# (30, 2)

# %%
YearsofExperience = f.YearsExperience.to_numpy()

# %%
YearsofExperience = YearsofExperience.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(YearsofExperience, f.Salary)
clf = LinearRegression()
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predicted = clf.predict(X_test)
expected = y_test

# %%
import seaborn as sns
sns.set_style('whitegrid')
sns.lmplot(x ='YearsExperience', y ='Salary', data = f)
