# %%
import keras
import numpy as np
from keras.datasets import cifar10
# loading the dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from keras.utils import to_categorical
from keras.optimizers import Adam

#X_train = X_train[:5000]
#y_train = y_train[:5000]
#X_test = X_test[:1000]
#y_test = y_test[:1000]

# Define a custom learning rate
learning_rate = 0.001
optimizer = Adam(learning_rate=learning_rate)

# building the input vector from the 32x32 pixels
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], X_train.shape[2], 3))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], X_test.shape[2], 3))
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# one-hot encoding using keras' numpy-related utilities
n_classes = 10
print("Shape before one-hot encoding: ", y_train.shape)
y_train = keras.utils.to_categorical(y_train, n_classes)
y_test = keras.utils.to_categorical(y_test, n_classes)
print("Shape after one-hot encoding: ", y_test.shape)

# building a linear stack of layers with the sequential model
model = Sequential()

# convolutional layer
model.add(Conv2D(8, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', input_shape=(32, 32, 3)))

# convolutional layer
model.add(Conv2D(16, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'))
model.add(Conv2D(16, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
#model.add(Dropout(0.25))

model.add(Conv2D(32, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'))
model.add(Conv2D(32, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'))
model.add(MaxPool2D(2,2))
#model.add(Dropout(0.25))

# flatten output of conv
model.add(Flatten())

# hidden layer
model.add(Dense(64, activation='relu'))
#model.add(Dropout(0.4))
#model.add(Dense(32, activation='relu'))
#model.add(Dropout(0.3))
# output layer
model.add(Dense(10, activation='softmax'))

# compiling the sequential model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=optimizer)

# training the model for 10 epochs
model.fit(X_train, y_train, batch_size=128, epochs=30, validation_data=(X_test, y_test))
# Out:
# Shape before one-hot encoding:  (50000, 1)
# Shape after one-hot encoding:  (10000, 10)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.3367 - loss: 1.8258 - val_accuracy: 0.5193 - val_loss: 1.3320
# Epoch 2/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5401 - loss: 1.2793 - val_accuracy: 0.5931 - val_loss: 1.1572
# Epoch 3/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.6130 - loss: 1.0936 - val_accuracy: 0.6333 - val_loss: 1.0361
# Epoch 4/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6610 - loss: 0.9649 - val_accuracy: 0.6759 - val_loss: 0.9425
# Epoch 5/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6938 - loss: 0.8791 - val_accuracy: 0.6712 - val_loss: 0.9471
# Epoch 6/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.7129 - loss: 0.8152 - val_accuracy: 0.6799 - val_loss: 0.9351
# Epoch 7/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7394 - loss: 0.7561 - val_accuracy: 0.6958 - val_loss: 0.8894
# Epoch 8/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7581 - loss: 0.6989 - val_accuracy: 0.7028 - val_loss: 0.8798
# Epoch 9/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7719 - loss: 0.6576 - val_accuracy: 0.7076 - val_loss: 0.8683
# Epoch 10/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7843 - loss: 0.6200 - val_accuracy: 0.7135 - val_loss: 0.8569
# Epoch 11/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7985 - loss: 0.5822 - val_accuracy: 0.7089 - val_loss: 0.8987
# Epoch 12/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8069 - loss: 0.5483 - val_accuracy: 0.7117 - val_loss: 0.8968
# Epoch 13/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8158 - loss: 0.5198 - val_accuracy: 0.7094 - val_loss: 0.8918
# Epoch 14/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8312 - loss: 0.4813 - val_accuracy: 0.7141 - val_loss: 0.9341
# Epoch 15/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8397 - loss: 0.4522 - val_accuracy: 0.7066 - val_loss: 0.9568
# Epoch 16/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8541 - loss: 0.4185 - val_accuracy: 0.7113 - val_loss: 1.0048
# Epoch 17/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8663 - loss: 0.3795 - val_accuracy: 0.7065 - val_loss: 1.0263
# Epoch 18/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8722 - loss: 0.3609 - val_accuracy: 0.6961 - val_loss: 1.0986
# Epoch 19/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8801 - loss: 0.3323 - val_accuracy: 0.7025 - val_loss: 1.1256
# Epoch 20/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8939 - loss: 0.3015 - val_accuracy: 0.7025 - val_loss: 1.1542
# Epoch 21/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9029 - loss: 0.2765 - val_accuracy: 0.6966 - val_loss: 1.2620
# Epoch 22/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9052 - loss: 0.2622 - val_accuracy: 0.6950 - val_loss: 1.3209
# Epoch 23/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9132 - loss: 0.2441 - val_accuracy: 0.6976 - val_loss: 1.3960
# Epoch 24/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9209 - loss: 0.2235 - val_accuracy: 0.6839 - val_loss: 1.5085
# Epoch 25/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9256 - loss: 0.2093 - val_accuracy: 0.6924 - val_loss: 1.5215
# Epoch 26/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9358 - loss: 0.1785 - val_accuracy: 0.6883 - val_loss: 1.6258
# Epoch 27/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9379 - loss: 0.1727 - val_accuracy: 0.6901 - val_loss: 1.6808
# Epoch 28/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9415 - loss: 0.1647 - val_accuracy: 0.6894 - val_loss: 1.7689
# Epoch 29/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9519 - loss: 0.1377 - val_accuracy: 0.6835 - val_loss: 1.7729
# Epoch 30/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9529 - loss: 0.1319 - val_accuracy: 0.6861 - val_loss: 1.8989

# %%
predictions = model.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %%
predictions = np.argmax(predictions, axis=1)

# %%
predictions[:5]
# Out:
# array([3, 8, 1, 0, 6])

# %%
y_test = np.argmax(y_test, axis=1)

# %%
y_test[:5]
# Out:
# array([3, 8, 8, 0, 6])
